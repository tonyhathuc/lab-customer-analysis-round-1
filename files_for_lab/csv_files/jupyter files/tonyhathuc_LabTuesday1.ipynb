# %% [markdown]
# # Lab | Customer Analysis Round 1
#
# #### Remember the process:
#
# 1. Case Study
# 2. Get data
# 3. Cleaning/Wrangling/EDA
# 4. Processing Data
# 5. Modeling
# 6. Validation
# 7. Reporting
#
# ### Abstract
#
# The objective of this data is to understand customer demographics and buying behavior. Later during the week, we will use predictive analytics to analyze the most profitable customers and how they interact. After that, we will take targeted actions to increase profitable customer response, retention, and growth.
#
# For this lab, we will gather the data from 3 _csv_ files that are provided in the `files_for_lab` folder. Use that data and complete the data cleaning tasks as mentioned later in the instructions.
#
# ### Instructions
#
# - Read the three files into python as dataframes
# - Show the DataFrame's shape.
# - Standardize header names.
# - Rearrange the columns in the dataframe as needed
# - Concatenate the three dataframes
# - Which columns are numerical?
# - Which columns are categorical?
# - Understand the meaning of all columns
# - Perform the data cleaning operations mentioned so far in class
#
#   - Delete the column education and the number of open complaints from the dataframe.
#   - Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change `dtype` to `numerical` type.
#   - Check for duplicate rows in the data and remove if any.
#   - Filter out the data for customers who have an income of 0 or less.

# %%
import numpy as np

import pandas as pd

# %%
# Read the three files into python as dataframes

df1 = pd.read_csv('file1.csv')
df2 = pd.read_csv('file2.csv')
df3 = pd.read_csv('file3.csv')

# %%
# Show the DataFrame's shape
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %% [markdown]
# ## Standardize header names

# %%
# I want to see the head of df1, df2, df3 to have an overview
df1.head(5)
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# 3            SUV          529.881344
# 4  Four-Door Car           17.269323

# %%
df2.head(5)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# 2   Personal Auto   Two-Door Car
# 3   Personal Auto     Luxury Car
# 4  Corporate Auto   Two-Door Car

# %%
df3.head(5)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# 0          499.200000   Two-Door Car
# 1            3.468912   Two-Door Car
# 2          393.600000  Four-Door Car
# 3          699.615192            SUV
# 4          484.800000            SUV

# %%
# So we want to convert the column names into lowercase to make it more clean
# We start with df1
df1.columns = df1.columns.str.lower()
df1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
# Rename the 'st' column into 'state'

df1.rename(columns={"st": "state"}, inplace=True)

# %%
# Check if that worked out
df1.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
# Now it is time to do the same for df2

df2.columns = df2.columns.str.lower()
df2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
# Rename the 'st' column into 'state' for df2 as well

df2.rename(columns={"st":"state"}, inplace=True)
df2.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
# Now we convert the column names into lowercase for df3

df3.columns = df3.columns.str.lower()
df3.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %% [markdown]
# ## Rearrange the columns in the dataframe as needed

# %%
# We start with df1
# Rearrange the columns into an intelligent order
# And then we will rearrange df2,df3 following df1's example

# %%
# Start with df1

df1 = df1[["customer", "state", "gender", "education", "income", "customer lifetime value", "monthly premium auto", 
          "number of open complaints", "policy type", "vehicle class", "total claim amount"]]

df1.head()
# Out:
#   customer       state gender             education   income  \
# 0  RB50392  Washington    NaN                Master      0.0
# 1  QZ44356     Arizona      F              Bachelor      0.0
# 2  AI49188      Nevada      F              Bachelor  48767.0
# 3  WW63253  California      M              Bachelor      0.0
# 4  GA49547  Washington      M  High School or Below  36357.0
#
#   customer lifetime value  monthly premium auto number of open complaints  \
# 0                     NaN                1000.0                    1/0/00
# 1              697953.59%                  94.0                    1/0/00
# 2             1288743.17%                 108.0                    1/0/00
# 3              764586.18%                 106.0                    1/0/00
# 4              536307.65%                  68.0                    1/0/00
#
#       policy type  vehicle class  total claim amount
# 0   Personal Auto  Four-Door Car            2.704934
# 1   Personal Auto  Four-Door Car         1131.464935
# 2   Personal Auto   Two-Door Car          566.472247
# 3  Corporate Auto            SUV          529.881344
# 4   Personal Auto  Four-Door Car           17.269323

# %%
# Now with df2

df2 = df2[["customer", "state", "gender", "education", "income", "customer lifetime value", "monthly premium auto", 
          "number of open complaints", "policy type", "vehicle class", "total claim amount"]]

df2.head()
# Out:
#   customer       state gender education  income customer lifetime value  \
# 0  GS98873     Arizona      F  Bachelor   16061              323912.47%
# 1  CW49887  California      F    Master   79487              462680.11%
# 2  MY31220  California      F   College   54230              899704.02%
# 3  UH35128      Oregon      F   College   71210             2580706.30%
# 4  WH52799     Arizona      F   College   94903              380812.21%
#
#    monthly premium auto number of open complaints     policy type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# 2   Two-Door Car               537.6
# 3     Luxury Car              1027.2
# 4   Two-Door Car               451.2

# %%
# Now with df3

df3 = df3[["customer", "state", "gender", "education", "income", "customer lifetime value", "monthly premium auto", 
          "number of open complaints", "policy type", "vehicle class", "total claim amount"]]

df3.head()
# Out:
#   customer       state gender             education  income  \
# 0  SA25987  Washington      M  High School or Below       0
# 1  TB86706     Arizona      M                Master       0
# 2  ZL73902      Nevada      F              Bachelor   25820
# 3  KX23516  California      F  High School or Below       0
# 4  FN77294  California      M  High School or Below   30366
#
#    customer lifetime value  monthly premium auto  number of open complaints  \
# 0              3479.137523                   104                          0
# 1              2502.637401                    66                          0
# 2              3265.156348                    82                          0
# 3              4455.843406                   121                          0
# 4              7704.958480                   101                          2
#
#      policy type  vehicle class  total claim amount
# 0  Personal Auto   Two-Door Car          499.200000
# 1  Personal Auto   Two-Door Car            3.468912
# 2  Personal Auto  Four-Door Car          393.600000
# 3  Personal Auto            SUV          699.615192
# 4  Personal Auto            SUV          484.800000

# %% [markdown]
# ## Concatenate the three dataframes

# %%
# Concatenate the three dataframes at once
# Store into the "df" variable

df = pd.concat([df1,df2,df3], axis=0)
df
# Out:
#      customer       state gender             education   income  \
# 0     RB50392  Washington    NaN                Master      0.0
# 1     QZ44356     Arizona      F              Bachelor      0.0
# 2     AI49188      Nevada      F              Bachelor  48767.0
# 3     WW63253  California      M              Bachelor      0.0
# 4     GA49547  Washington      M  High School or Below  36357.0
# ...       ...         ...    ...                   ...      ...
# 7065  LA72316  California      M              Bachelor  71941.0
# 7066  PK87824  California      F               College  21604.0
# 7067  TD14365  California      M              Bachelor      0.0
# 7068  UP19263  California      M               College  21941.0
# 7069  Y167826  California      M               College      0.0
#
#      customer lifetime value  monthly premium auto number of open complaints  \
# 0                        NaN                1000.0                    1/0/00
# 1                 697953.59%                  94.0                    1/0/00
# 2                1288743.17%                 108.0                    1/0/00
# 3                 764586.18%                 106.0                    1/0/00
# 4                 536307.65%                  68.0                    1/0/00
# ...                      ...                   ...                       ...
# 7065             23405.98798                  73.0                         0
# 7066             3096.511217                  79.0                         0
# 7067             8163.890428                  85.0                         3
# 7068             7524.442436                  96.0                         0
# 7069             2611.836866                  77.0                         0
#
#          policy type  vehicle class  total claim amount
# 0      Personal Auto  Four-Door Car            2.704934
# 1      Personal Auto  Four-Door Car         1131.464935
# 2      Personal Auto   Two-Door Car          566.472247
# 3     Corporate Auto            SUV          529.881344
# 4      Personal Auto  Four-Door Car           17.269323
# ...              ...            ...                 ...
# 7065   Personal Auto  Four-Door Car          198.234764
# 7066  Corporate Auto  Four-Door Car          379.200000
# 7067  Corporate Auto  Four-Door Car          790.784983
# 7068   Personal Auto  Four-Door Car          691.200000
# 7069  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 11 columns]

# %%
# Check NA values

df.isna().sum()
# Out:
# customer                     2937
# state                        2937
# gender                       3059
# education                    2937
# income                       2937
# customer lifetime value      2944
# monthly premium auto         2937
# number of open complaints    2937
# policy type                  2937
# vehicle class                2937
# total claim amount           2937
# dtype: int64

# %%
# 4008 + 996 + 7070 = 12074 rows
# the concatenation was successful :)

# %% [markdown]
# ## Which columns are numerical?

# %%
# Get numeric data and store in the dfnum variable
# These columns are numerical

dfnum = df._get_numeric_data()
dfnum

# would consider "customer lifetime value" and "number of open complaints" as well
# just need to clean them
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %% [markdown]
# ## Which columns are categorical?
#
# customer, state, gender, education, policy class, vehicle class

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   income                     9137 non-null   float64
#  5   customer lifetime value    9130 non-null   object
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Understand the meaning of all columns

# %%
df.describe()
# Out:
#              income  monthly premium auto  total claim amount
# count   9137.000000           9137.000000         9137.000000
# mean   37828.820291            110.391266          430.527140
# std    30358.716159            581.376032          289.582968
# min        0.000000             61.000000            0.099007
# 25%        0.000000             68.000000          266.996814
# 50%    34244.000000             83.000000          377.561463
# 75%    62447.000000            109.000000          546.420009
# max    99981.000000          35354.000000         2893.239678

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   income                     9137 non-null   float64
#  5   customer lifetime value    9130 non-null   object
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Perform the data cleaning operations mentioned so far in class

# %% [markdown]
# ## Delete the column education and the number of open complaints from the dataframe.

# %%
# Delete the "education" and the "number of open complaints" from the dataframe
df = df[["customer", "state", "gender", "income", "customer lifetime value", "monthly premium auto",
         "policy type", "vehicle class", "total claim amount"]]
df
# Out:
#      customer       state gender   income customer lifetime value  \
# 0     RB50392  Washington    NaN      0.0                     NaN
# 1     QZ44356     Arizona      F      0.0              697953.59%
# 2     AI49188      Nevada      F  48767.0             1288743.17%
# 3     WW63253  California      M      0.0              764586.18%
# 4     GA49547  Washington      M  36357.0              536307.65%
# ...       ...         ...    ...      ...                     ...
# 7065  LA72316  California      M  71941.0             23405.98798
# 7066  PK87824  California      F  21604.0             3096.511217
# 7067  TD14365  California      M      0.0             8163.890428
# 7068  UP19263  California      M  21941.0             7524.442436
# 7069  Y167826  California      M      0.0             2611.836866
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# 3                    106.0  Corporate Auto            SUV          529.881344
# 4                     68.0   Personal Auto  Four-Door Car           17.269323
# ...                    ...             ...            ...                 ...
# 7065                  73.0   Personal Auto  Four-Door Car          198.234764
# 7066                  79.0  Corporate Auto  Four-Door Car          379.200000
# 7067                  85.0  Corporate Auto  Four-Door Car          790.784983
# 7068                  96.0   Personal Auto  Four-Door Car          691.200000
# 7069                  77.0  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 9 columns]

# %% [markdown]
# ## Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change `dtype` to `numerical` type.

# %%
df["customer lifetime value"]

# the dtype is object currently
# Out:
# 0               NaN
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 7065    23405.98798
# 7066    3096.511217
# 7067    8163.890428
# 7068    7524.442436
# 7069    2611.836866
# Name: customer lifetime value, Length: 12074, dtype: object

# %%
df["customer lifetime value"] = df["customer lifetime value"].str.rstrip("%").astype("float") *100.0

df
# Out:
# <ipython-input-48-37e7ad641dff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customer lifetime value"] = df["customer lifetime value"].str.rstrip("%").astype("float") *100.0
#      customer       state gender   income  customer lifetime value  \
# 0     RB50392  Washington    NaN      0.0                      NaN
# 1     QZ44356     Arizona      F      0.0               69795359.0
# 2     AI49188      Nevada      F  48767.0              128874317.0
# 3     WW63253  California      M      0.0               76458618.0
# 4     GA49547  Washington      M  36357.0               53630765.0
# ...       ...         ...    ...      ...                      ...
# 7065  LA72316  California      M  71941.0                      NaN
# 7066  PK87824  California      F  21604.0                      NaN
# 7067  TD14365  California      M      0.0                      NaN
# 7068  UP19263  California      M  21941.0                      NaN
# 7069  Y167826  California      M      0.0                      NaN
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# 3                    106.0  Corporate Auto            SUV          529.881344
# 4                     68.0   Personal Auto  Four-Door Car           17.269323
# ...                    ...             ...            ...                 ...
# 7065                  73.0   Personal Auto  Four-Door Car          198.234764
# 7066                  79.0  Corporate Auto  Four-Door Car          379.200000
# 7067                  85.0  Corporate Auto  Four-Door Car          790.784983
# 7068                  96.0   Personal Auto  Four-Door Car          691.200000
# 7069                  77.0  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 9 columns]

# %%
# Check NA values

df.isna().sum()
# Out:
# customer                    2937
# state                       2937
# gender                      3059
# income                      2937
# customer lifetime value    10014
# monthly premium auto        2937
# policy type                 2937
# vehicle class               2937
# total claim amount          2937
# dtype: int64

# %%
# It's a lot. I did probably something wrong.

# %%
# Here I want to see the % of nules 
# Customer lifetime value has the highest percent of nulls

# Maybe I should drop the "customer lifetime value" column
df.isna().mean().round(4) *100
# Out:
# customer                   24.32
# state                      24.32
# gender                     25.34
# income                     24.32
# customer lifetime value    82.94
# monthly premium auto       24.32
# policy type                24.32
# vehicle class              24.32
# total claim amount         24.32
# dtype: float64

# %% [markdown]
# ## Check for duplicate rows in the data and remove if any.

# %%
# Check for duplicate rows in df
df.duplicated(subset=None, keep="first").sum()
# Out:
# 2943

# %%
# Testing with a query
df.drop_duplicates()
# Out:
#      customer       state gender   income  customer lifetime value  \
# 0     RB50392  Washington    NaN      0.0                      NaN
# 1     QZ44356     Arizona      F      0.0               69795359.0
# 2     AI49188      Nevada      F  48767.0              128874317.0
# 3     WW63253  California      M      0.0               76458618.0
# 4     GA49547  Washington      M  36357.0               53630765.0
# ...       ...         ...    ...      ...                      ...
# 7065  LA72316  California      M  71941.0                      NaN
# 7066  PK87824  California      F  21604.0                      NaN
# 7067  TD14365  California      M      0.0                      NaN
# 7068  UP19263  California      M  21941.0                      NaN
# 7069  Y167826  California      M      0.0                      NaN
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# 3                    106.0  Corporate Auto            SUV          529.881344
# 4                     68.0   Personal Auto  Four-Door Car           17.269323
# ...                    ...             ...            ...                 ...
# 7065                  73.0   Personal Auto  Four-Door Car          198.234764
# 7066                  79.0  Corporate Auto  Four-Door Car          379.200000
# 7067                  85.0  Corporate Auto  Four-Door Car          790.784983
# 7068                  96.0   Personal Auto  Four-Door Car          691.200000
# 7069                  77.0  Corporate Auto   Two-Door Car          369.600000
#
# [9131 rows x 9 columns]

# %%
df = df.drop_duplicates()
df
# Out:
#      customer       state gender   income  customer lifetime value  \
# 0     RB50392  Washington    NaN      0.0                      NaN
# 1     QZ44356     Arizona      F      0.0               69795359.0
# 2     AI49188      Nevada      F  48767.0              128874317.0
# 3     WW63253  California      M      0.0               76458618.0
# 4     GA49547  Washington      M  36357.0               53630765.0
# ...       ...         ...    ...      ...                      ...
# 7065  LA72316  California      M  71941.0                      NaN
# 7066  PK87824  California      F  21604.0                      NaN
# 7067  TD14365  California      M      0.0                      NaN
# 7068  UP19263  California      M  21941.0                      NaN
# 7069  Y167826  California      M      0.0                      NaN
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# 3                    106.0  Corporate Auto            SUV          529.881344
# 4                     68.0   Personal Auto  Four-Door Car           17.269323
# ...                    ...             ...            ...                 ...
# 7065                  73.0   Personal Auto  Four-Door Car          198.234764
# 7066                  79.0  Corporate Auto  Four-Door Car          379.200000
# 7067                  85.0  Corporate Auto  Four-Door Car          790.784983
# 7068                  96.0   Personal Auto  Four-Door Car          691.200000
# 7069                  77.0  Corporate Auto   Two-Door Car          369.600000
#
# [9131 rows x 9 columns]

# %% [markdown]
# ## Filter out the data for customers who have an income of 0 or less

# %%
# let's do it with .loc

df.loc[df.income <= 0]
# Out:
#      customer       state gender  income  customer lifetime value  \
# 0     RB50392  Washington    NaN     0.0                      NaN
# 1     QZ44356     Arizona      F     0.0               69795359.0
# 3     WW63253  California      M     0.0               76458618.0
# 7     CF85061     Arizona      M     0.0               72161003.0
# 10    SX51350  California      M     0.0               47389920.0
# ...       ...         ...    ...     ...                      ...
# 7059  WZ45103  California      F     0.0                      NaN
# 7061  RX91025  California      M     0.0                      NaN
# 7062  AC13887  California      M     0.0                      NaN
# 7067  TD14365  California      M     0.0                      NaN
# 7069  Y167826  California      M     0.0                      NaN
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# 3                    106.0  Corporate Auto            SUV          529.881344
# 7                    101.0  Corporate Auto  Four-Door Car          363.029680
# 10                    67.0   Personal Auto  Four-Door Car          482.400000
# ...                    ...             ...            ...                 ...
# 7059                  76.0   Personal Auto  Four-Door Car          364.800000
# 7061                 185.0   Personal Auto            SUV         1950.725547
# 7062                  67.0  Corporate Auto   Two-Door Car          482.400000
# 7067                  85.0  Corporate Auto  Four-Door Car          790.784983
# 7069                  77.0  Corporate Auto   Two-Door Car          369.600000
#
# [2293 rows x 9 columns]

# %%
# Now we need to reset the index

df = df.reset_index(drop=True)
